# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Tiago Nascimento__

# %% [markdown]
# Actually I'm a nurse manager

# %% [markdown]
# _I am interested in data science because I want to analyse great amounts of data, and generate better outcomes for my work!_

# %% [markdown]
# ### In Cell 5, i'll do simple math, to execute my code

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# - Portugal
# - Spain
# - France
# - Germany
# - Italy
# - Greece
#
# 1. one
# 2. two
# 3. three
# 4. four
# 5. five
# 6. six
#
# ***
#
# [Best Courses Ever!](http://www.coursera.org)
